# %% [markdown]
# # Create regulatory domains

# %% [markdown]
# This is an example of code allowing the use of the create_regdom function to create gene regulatory domains from a file containing the size of the chromosomes and a file containing the tss. Both files must be in .bed format documentation here: http://genome.ucsc.edu/FAQ/FAQformat#format1

# %% [markdown]
# ## For hg38

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import greatpy as great

# %%
regdom_hg38 = great.tl.create_regdom(
    tss_file="../../data/human/tss.bed",
    chr_sizes_file="../../data/human/chr_size.bed",
    association_rule="Basalplusextention",
    out_path=None
    )
regdom_hg38
# Out:
#         Chr  Chr_Start   Chr_End       name       tss Strand
# 0      chr1          0     22436  MIR6859-1     17436      -
# 1      chr1      16436     22436  MIR6859-2     17436      -
# 2      chr1      16436     22436  MIR6859-3     17436      -
# 3      chr1      16436     28370  MIR6859-4     17436      -
# 4      chr1      22436     34370     WASH7P     29370      -
# ...     ...        ...       ...        ...       ...    ...
# 23223  chrY   24219831  24828819       DAZ3  24813492      -
# 23224  chrY   24818492  25051104       DAZ4  24833819      +
# 23227  chrY   24834819  25057104       BPY2  25052104      -
# 23225  chrY   25051104  25057104      BPY2B  25052104      -
# 23226  chrY   25051104  26052104      BPY2C  25052104      -
#
# [23228 rows x 6 columns]

# %% [markdown]
# ## For hg19

# %%
regdom_hg19 = great.tl.create_regdom(
    tss_file="/storage/groups/ml01/datasets/annotations/hg19/TSS.in",
    chr_sizes_file="/storage/groups/ml01/datasets/annotations/hg19/hg19.chrom.sizes",
    association_rule="Basalplusextention",
    out_path=None
    )
regdom_hg19
# Out:
#         Chr  Chr_Start   Chr_End        name       tss Strand
# 0      chr1          0     22436   MIR6859-3     17436      -
# 1      chr1      16436     28370   MIR6859-4     17436      -
# 2      chr1      22436     34370      WASH7P     29370      -
# 3      chr1      28370     34370      WASH7P     29370      -
# 4      chr1      25366     35081  MIR1302-10     30366      +
# ...     ...        ...       ...         ...       ...    ...
# 26424  chrY   26338378  26711349   GOLGA2P2Y  26360978      -
# 26425  chrY   26365978  26717349       TTTY4  26716349      +
# 26426  chrY   26711349  26717349       TTTY4  26716349      +
# 26427  chrY   26711349  26759151       TTTY4  26716349      +
# 26428  chrY   26717349  27764151        BPY2  26764151      +
#
# [26429 rows x 6 columns]
